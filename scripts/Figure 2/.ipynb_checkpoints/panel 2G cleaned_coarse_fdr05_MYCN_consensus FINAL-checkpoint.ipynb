# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import anndata as ad
import warnings
import pickle as pkl
import sccoda

from sccoda.util import comp_ana as mod
from sccoda.util import cell_composition_data as dat
from sccoda.util import data_visualization as viz

import tensorflow as tf
tf.random.set_seed(1)  # setting the same seed makes multiple runs of scCODA exactly reproducible

warnings.filterwarnings("ignore")

basedir = "/Users/apatel2/Documents/github/HTAPP_neuroblastoma/output/Fig2/"

#resolution = "fine"  # use fine or coarse resolution to define cell types
resolution = "coarse"
countsfile = f"{basedir}cell_counts.csv"
#"cleaned" file has erythrocytes and zona glomerulosa cell counts removed

model_specs = [("MYCN", "C(MYCN, Treatment('non-amplified'))")]

# %%
# Read counts file into scCODA
cell_counts = pd.read_csv(countsfile, skip_blank_lines = True)
#sampletracking.dropna(axis=0, how='all', inplace = True)
cell_counts = cell_counts.drop(columns=['Unnamed: 0'])

first_covariate_index = cell_counts.columns.tolist().index('orig.ident')
cell_counts.columns[first_covariate_index:]

# Subset counts data to only look at nucleus samples
# cell_counts = cell_counts[cell_counts['condition'] == "nucleus"]
cell_counts.head()

data_nb = dat.from_pandas(cell_counts, covariate_columns=cell_counts.columns[first_covariate_index:])
print(data_nb.X)
print(data_nb.obs)

#remove "unknown" methylation groups
#data_nb = data_nb[data_nb.obs["Methylation_Group"].isin(["1", "2","3", "4"])]
#print(data_nb.obs)
# Out:
# [[  850  2743  1666   959]
#  [  328   616  6930   287]
#  [  655  2159  3918   818]
#  [  320   683  7578   198]
#  [ 1858   852  2706  2788]
#  [  112   343  6414   233]
#  [ 5992   655  1138  8901]
#  [  167  1698  5172   212]
#  [    0    88  7339    18]
#  [ 1038  4011  6991  1921]
#  [  338   168  7320   582]
#  [    0    90  6008   183]
#  [  428  1542  9358  1123]
#  [ 1345  1170  2949  4860]
#  [  262   637  6950   117]
#  [  480     0  6516     0]
#  [ 1671  1190   281   567]
#  [   75   197  2508     0]
#  [  673  8651 13434   417]
#  [  525   617  7531   293]
#  [  325   210  6804  1054]
#  [  117   524  4904   122]
#  [    0     0  5595   114]
#  [  316  1369  5340   287]
#  [  270  1502  4886   324]
#  [  150   766 11224   518]
#  [  597   635  3098   675]
#  [  244  1116 25555   662]
#  [    0    78  4995     0]
#  [  203   817  1999   533]
#  [ 1018   376  3447  4855]
#  [ 1931  3159  5697  6455]
#  [    0   895 10916  2714]
#  [ 2243   227   942  3448]
#  [  106  1253  4318   314]
#  [  649  2467 13570   534]
#  [  303   878 25173   133]
#  [ 2584  2296  4924  8065]
#  [  259  2844 11169   720]
#  [    0   546  8372    59]
#  [  176   318  2545   517]
#  [    0   472  1880   127]
#  [  260   191  6214   233]
#  [  480   329  2517   526]
#  [    0   110  6565     0]
#  [  736   600  3390  1615]
#  [    0   118  2944   103]]
#                 orig.ident condition           MYCN        ALK INSS_Stage
# 0          HTAPP-100-SMP-1   nucleus  non-amplified  wild type          4  \
# 1         HTAPP-102-SMP-11   nucleus  non-amplified  wild type          3
# 2         HTAPP-114-SMP-21   nucleus  non-amplified  wild type          1
# 3         HTAPP-116-SMP-31   nucleus  non-amplified     mutant          4
# 4         HTAPP-120-SMP-41   nucleus  non-amplified     mutant          1
# 5         HTAPP-123-SMP-51   nucleus  non-amplified  wild type          1
# 6         HTAPP-125-SMP-71   nucleus  non-amplified  wild type          3
# 7         HTAPP-126-SMP-81   nucleus  non-amplified  wild type          1
# 8         HTAPP-130-SMP-91   nucleus      amplified     mutant          4
# 9        HTAPP-136-SMP-102   nucleus  non-amplified  wild type         2B
# 10       HTAPP-141-SMP-111   nucleus  non-amplified  wild type          4
# 11       HTAPP-141-SMP-119   nucleus  non-amplified  wild type          4
# 12       HTAPP-146-SMP-131   nucleus  non-amplified  wild type         2A
# 13       HTAPP-148-SMP-141   nucleus  non-amplified     mutant         2A
# 14       HTAPP-155-SMP-151   nucleus  non-amplified  wild type          1
# 15       HTAPP-159-SMP-171      cell      amplified     mutant          4
# 16       HTAPP-163-SMP-181      cell  non-amplified  wild type          4
# 17       HTAPP-164-SMP-191      cell      amplified  wild type         4S
# 18       HTAPP-168-SMP-221      cell  non-amplified  wild type          4
# 19       HTAPP-171-SMP-231   nucleus      amplified  wild type          4
# 20       HTAPP-184-SMP-241   nucleus  non-amplified    unknown          4
# 21       HTAPP-194-SMP-251   nucleus      amplified  wild type          4
# 22       HTAPP-195-SMP-261   nucleus      amplified  wild type         2B
# 23       HTAPP-196-SMP-271   nucleus  non-amplified  wild type          4
# 24       HTAPP-198-SMP-281   nucleus  non-amplified    unknown          4
# 25      HTAPP-204-SMP-6601   nucleus  non-amplified  wild type         2A
# 26       HTAPP-233-SMP-361   nucleus      amplified    unknown          3
# 27       HTAPP-244-SMP-451   nucleus  non-amplified  wild type          1
# 28       HTAPP-312-SMP-901      cell  non-amplified  wild type         2A
# 29       HTAPP-312-SMP-902      cell  non-amplified  wild type         2A
# 30      HTAPP-437-SMP-1861   nucleus  non-amplified    unknown    unknown
# 31      HTAPP-527-SMP-6767   nucleus  non-amplified  wild type    unknown
# 32      HTAPP-621-SMP-3181   nucleus  non-amplified    unknown    unknown
# 33  HTAPP-656-SMP-3481_TST   nucleus  non-amplified  wild type          4
# 34      HTAPP-672-SMP-8509      cell  non-amplified    unknown          3
# 35      HTAPP-683-SMP-6769   nucleus  non-amplified  wild type         4S
# 36      HTAPP-756-SMP-6779   nucleus  non-amplified    unknown          3
# 37      HTAPP-768-SMP-6781   nucleus  non-amplified  wild type          3
# 38      HTAPP-800-SMP-6783   nucleus  non-amplified    unknown         2B
# 39      HTAPP-800-SMP-6784   nucleus  non-amplified    unknown         2B
# 40      HTAPP-803-SMP-6786   nucleus  non-amplified     mutant          4
# 41      HTAPP-811-SMP-6832   nucleus      amplified     mutant          4
# 42      HTAPP-811-SMP-6833   nucleus      amplified     mutant          4
# 43      HTAPP-811-SMP-6834   nucleus      amplified     mutant          4
# 44      HTAPP-813-SMP-6848      cell  non-amplified  wild type         4S
# 45      HTAPP-829-SMP-6975   nucleus  non-amplified  wild type          4
# 46      HTAPP-931-SMP-7448      cell  non-amplified    unknown         4S
#
#    INRGSS_Stage      Sample             Treatment_Status anti_GD2
# 0             M     primary  treated_chemo-immunotherapy      Yes  \
# 1            L2     primary                    untreated      NaN
# 2            L1     primary                    untreated      NaN
# 3             M     primary                    untreated      NaN
# 4            L1     primary                    untreated      NaN
# 5            L1     primary                    untreated      NaN
# 6            L2     primary                    untreated      NaN
# 7            L1     primary                    untreated      NaN
# 8             M     primary                    untreated      NaN
# 9            L1     primary                    untreated      NaN
# 10            M     primary                    untreated      NaN
# 11            M     primary                    untreated      NaN
# 12           L1     primary                    untreated      NaN
# 13           L1     primary                    untreated      NaN
# 14           L1     primary                    untreated      NaN
# 15            M     primary         treated_chemotherapy       No
# 16            M     primary         treated_chemotherapy       No
# 17           Ms     primary                    untreated      NaN
# 18            M     primary  treated_chemo-immunotherapy      Yes
# 19            M     primary         treated_chemotherapy       No
# 20            M     primary         treated_chemotherapy       No
# 21            M     primary         treated_chemotherapy       No
# 22           L2     primary                    untreated      NaN
# 23            M     primary  treated_chemo-immunotherapy      Yes
# 24            M     primary         treated_chemotherapy       No
# 25           L1     primary                    untreated  Unknown
# 26      unknown     primary         treated_chemotherapy       No
# 27      unknown     primary                      unknown  unknown
# 28           L2     primary                    untreated      NaN
# 29           L2     primary         treated_chemotherapy       No
# 30      unknown     primary                      unknown  unknown
# 31           L2     primary         treated_chemotherapy       No
# 32           L1     primary                      unknown  unknown
# 33      unknown     primary         treated_chemotherapy       No
# 34           L2     primary         treated_chemotherapy       No
# 35      unknown     primary         treated_chemotherapy       No
# 36      unknown     primary         treated_chemotherapy       No
# 37      unknown     primary         treated_chemotherapy       No
# 38      unknown     primary                      unknown  unknown
# 39      unknown     primary                      unknown  unknown
# 40            M     primary  treated_chemo-immunotherapy      Yes
# 41            M     primary  treated_chemo-immunotherapy      Yes
# 42            M     primary  treated_chemo-immunotherapy      Yes
# 43            M     primary  treated_chemo-immunotherapy      Yes
# 44           Ms  metastasis                    untreated      NaN
# 45            M     primary  treated_chemo-immunotherapy      Yes
# 46           Ms     primary                    untreated      NaN
#
#    Methylation_Group      COG_Risk
# 0                  1          High
# 1                  2  Intermediate
# 2                  2           Low
# 3                  2          High
# 4                  2           Low
# 5                  2           Low
# 6                  2  Intermediate
# 7                  3           Low
# 8                  4          High
# 9                  2           Low
# 10                 2          High
# 11                 2          High
# 12                 1           Low
# 13           unknown           Low
# 14                 2           Low
# 15                 4          High
# 16                 2          High
# 17                 2          High
# 18                 2          High
# 19                 4          High
# 20                 1          High
# 21                 2          High
# 22                 4          High
# 23                 1          High
# 24                 2          High
# 25                 2           Low
# 26           unknown          High
# 27           unknown           Low
# 28           unknown  Intermediate
# 29           unknown  Intermediate
# 30           unknown           Low
# 31           unknown  Intermediate
# 32           unknown           Low
# 33           unknown  Intermediate
# 34           unknown          High
# 35           unknown  Intermediate
# 36           unknown          High
# 37           unknown  Intermediate
# 38           unknown           Low
# 39           unknown           Low
# 40                 2          High
# 41                 2          High
# 42                 2          High
# 43                 2          High
# 44           unknown           Low
# 45                 2          High
# 46                 3           Low

# %%
viz.rel_abundance_dispersion_plot(
    data=data_nb,
    abundant_threshold=0.9
)
plt.show()

# %%
tf.random.set_seed(1)

i = 0
feature = model_specs[i][0]
formula = model_specs[i][1]

cell_types = data_nb.var.index
results_cycle = pd.DataFrame(index=cell_types, columns=["times_credible"]).fillna(0)

for feature, formula in model_specs:
    for ct in cell_types:
        print(f"feature: {feature}")
        print(f"formula: {formula}")
        print(f"Reference: {ct}")

        viz.boxplots(data_nb, feature_name=feature, plot_facets=False, y_scale="relative", add_dots=False)
        plt.savefig(f"{basedir}/{feature}.pdf", bbox_inches="tight")
        plt.show()
        
        # Run inference
        model_temp = mod.CompositionalAnalysis(data_nb, formula=model_specs[i][1], reference_cell_type=ct)
        temp_results = model_temp.sample_hmc()
        temp_results.summary()
        print(temp_results.credible_effects())
                     
        # Select credible effects
        cred_eff = temp_results.credible_effects()
        cred_eff.index = cred_eff.index.droplevel(level=0)
        
        # add up credible effects'
        results_cycle["times_credible"] += cred_eff.astype("int")
        
    results_cycle["pct_credible"] = results_cycle["times_credible"]/len(cell_types)
    results_cycle["is_credible"] = results_cycle["pct_credible"] >= 0.5
    print(results_cycle)
# Out:
# feature: MYCN
# formula: C(MYCN, Treatment('non-amplified'))
# Reference: endothelium
# Zero counts encountered in data! Added a pseudocount of 0.5.
# 100%|████████████████████████████████████| 20000/20000 [00:30<00:00, 664.62it/s]
# WARNING:tensorflow:5 out of the last 5 calls to <function CompositionalModel.sampling.<locals>.sample_mcmc at 0x3a0b3ee80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MCMC sampling finished. (38.343 sec)
# Acceptance rate: 58.4%
# Compositional Analysis summary:
#
# Data: 47 samples, 4 cell types
# Reference index: 0
# Formula: C(MYCN, Treatment('non-amplified'))
#
# Intercepts:
#              Final Parameter  Expected Sample
# Cell Type
# endothelium           -0.957       872.210920
# immune                -0.390      1537.681859
# malignant              0.938      5802.425363
# stroma                -0.624      1216.862709
#
#
# Effects:
#                                                               Final Parameter
# Covariate                                        Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified] endothelium              0.0  \
#                                                  immune                   0.0
#                                                  malignant                0.0
#                                                  stroma                   0.0
#
#                                                               Expected Sample
# Covariate                                        Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified] endothelium       872.210920  \
#                                                  immune           1537.681859
#                                                  malignant        5802.425363
#                                                  stroma           1216.862709
#
#                                                               log2-fold change
# Covariate                                        Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified] endothelium               0.0
#                                                  immune                    0.0
#                                                  malignant                 0.0
#                                                  stroma                    0.0
# Covariate                                         Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified]  endothelium    False
#                                                   immune         False
#                                                   malignant      False
#                                                   stroma         False
# Name: Final Parameter, dtype: bool
# feature: MYCN
# formula: C(MYCN, Treatment('non-amplified'))
# Reference: immune
# Zero counts encountered in data! Added a pseudocount of 0.5.
# 100%|████████████████████████████████████| 20000/20000 [00:29<00:00, 674.55it/s]
# WARNING:tensorflow:6 out of the last 6 calls to <function CompositionalModel.sampling.<locals>.sample_mcmc at 0x3aa2f6700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MCMC sampling finished. (37.911 sec)
# Acceptance rate: 53.8%
# Compositional Analysis summary:
#
# Data: 47 samples, 4 cell types
# Reference index: 1
# Formula: C(MYCN, Treatment('non-amplified'))
#
# Intercepts:
#              Final Parameter  Expected Sample
# Cell Type
# endothelium           -0.983       866.103052
# immune                -0.430      1505.686018
# malignant              0.922      5819.699453
# stroma                -0.626      1237.692328
#
#
# Effects:
#                                                               Final Parameter
# Covariate                                        Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified] endothelium         0.000000  \
#                                                  immune              0.000000
#                                                  malignant           1.001059
#                                                  stroma              0.000000
#
#                                                               Expected Sample
# Covariate                                        Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified] endothelium       419.968806  \
#                                                  immune            730.099217
#                                                  malignant        7678.962339
#                                                  stroma            600.150489
#
#                                                               log2-fold change
# Covariate                                        Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified] endothelium         -1.044257
#                                                  immune              -1.044257
#                                                  malignant            0.399967
#                                                  stroma              -1.044257
# Covariate                                         Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified]  endothelium    False
#                                                   immune         False
#                                                   malignant       True
#                                                   stroma         False
# Name: Final Parameter, dtype: bool
# feature: MYCN
# formula: C(MYCN, Treatment('non-amplified'))
# Reference: malignant
# Zero counts encountered in data! Added a pseudocount of 0.5.
# 100%|████████████████████████████████████| 20000/20000 [00:30<00:00, 658.55it/s]
# MCMC sampling finished. (38.662 sec)
# Acceptance rate: 82.0%
# Compositional Analysis summary:
#
# Data: 47 samples, 4 cell types
# Reference index: 2
# Formula: C(MYCN, Treatment('non-amplified'))
#
# Intercepts:
#              Final Parameter  Expected Sample
# Cell Type
# endothelium           -1.149       998.568630
# immune                -7.043         2.751986
# malignant              0.770      6804.387361
# stroma                -0.663      1623.472874
#
#
# Effects:
#                                                               Final Parameter
# Covariate                                        Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified] endothelium         0.000000  \
#                                                  immune            379.814834
#                                                  malignant           0.000000
#                                                  stroma              0.000000
#
#                                                               Expected Sample
# Covariate                                        Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified] endothelium    3.825772e-159  \
#                                                  immune          9.429181e+03
#                                                  malignant      2.606935e-158
#                                                  stroma         6.219941e-159
#
#                                                               log2-fold change
# Covariate                                        Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified] endothelium       -536.214534
#                                                  immune              11.742444
#                                                  malignant         -536.214534
#                                                  stroma            -536.214534
# Covariate                                         Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified]  endothelium    False
#                                                   immune          True
#                                                   malignant      False
#                                                   stroma         False
# Name: Final Parameter, dtype: bool
# feature: MYCN
# formula: C(MYCN, Treatment('non-amplified'))
# Reference: stroma
# Zero counts encountered in data! Added a pseudocount of 0.5.
# 100%|████████████████████████████████████| 20000/20000 [00:30<00:00, 659.61it/s]
# MCMC sampling finished. (38.586 sec)
# Acceptance rate: 67.9%
# Compositional Analysis summary:
#
# Data: 47 samples, 4 cell types
# Reference index: 3
# Formula: C(MYCN, Treatment('non-amplified'))
#
# Intercepts:
#              Final Parameter  Expected Sample
# Cell Type
# endothelium           -0.983       858.358823
# immune                -0.393      1548.469373
# malignant              0.930      5813.989183
# stroma                -0.641      1208.363472
#
#
# Effects:
#                                                               Final Parameter
# Covariate                                        Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified] endothelium         0.000000  \
#                                                  immune              0.000000
#                                                  malignant           0.984475
#                                                  stroma              0.000000
#
#                                                               Expected Sample
# Covariate                                        Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified] endothelium       422.074921  \
#                                                  immune            761.418267
#                                                  malignant        7651.507347
#                                                  stroma            594.180316
#
#                                                               log2-fold change
# Covariate                                        Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified] endothelium         -1.024082
#                                                  immune              -1.024082
#                                                  malignant            0.396216
#                                                  stroma              -1.024082
# Covariate                                         Cell Type
# C(MYCN, Treatment('non-amplified'))[T.amplified]  endothelium    False
#                                                   immune         False
#                                                   malignant       True
#                                                   stroma         False
# Name: Final Parameter, dtype: bool
#              times_credible  pct_credible  is_credible
# endothelium               0          0.00        False
# immune                    1          0.25        False
# malignant                 2          0.50         True
# stroma                    0          0.00        False
